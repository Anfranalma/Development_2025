# %% [markdown]
# Tuples, inmutable objest, we can create them but not reassing elements inside of them

# %%
my_tuples = "Angel",23, True
my_tuple2 = ("Alberto", 22, False)
that_tuple = "Joaquin"

print(type(my_tuples))
print(type(that_tuple))

that_other_tubple = ("Brenda",)
print(type(that_other_tubple))

print(my_tuple2[2])
# Out:
# <class 'tuple'>
# <class 'str'>
# <class 'tuple'>
# False

# %%
my_tuple3 = ('a','p','p','l','e')

print(my_tuple3.count('p'))

print(my_tuple3.index('p'))

that_array = []
that_array = my_tuple3[:]
print(that_array[2:3])
that_array[2]='b'
print(that_array)
# Out:
# 2
# 1
# ('p',)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 10
#       8 that_array = my_tuple3[:]
#       9 print(that_array[2:3])
# ---> 10 that_array[2]='b'
#      11 print(that_array)
#
# TypeError: 'tuple' object does not support item assignment

# %%
array = ['---',
'| |',
'---',
'| |',
'---']

# %%
import pyfiglet

ascii_art = pyfiglet.figlet_format("6")
print(ascii_art)
# Out:
#   __
#  / /_
# | '_ \
# | (_) |
#  \___/
